# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2024-08-17  12:30  Premier League  Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2024-08-25  16:30  Premier League  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2024-09-01  16:00  Premier League  Matchweek 3  Sun  Away      W  3.0  0.0
# 3  2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      L  0.0  1.0
# 5  2024-09-21  15:00  Premier League  Matchweek 5  Sat  Home      W  3.0  0.0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0     Ipswich Town  ...  Match Report    NaN  18.0   5.0  14.8  0.0  0     0
# 1        Brentford  ...  Match Report    NaN  19.0   8.0  13.6  1.0  0     0
# 2   Manchester Utd  ...  Match Report    NaN  11.0   3.0  13.4  0.0  0     0
# 3  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0  14.9  0.0  0     0
# 5      Bournemouth  ...  Match Report    NaN  19.0  12.0  16.6  0.0  0     0
#
#   season       team
# ...

# %%
matches.shape
# Out:
# (3240, 28)

# %%
38 * 20 * 5
# Out:
# 3800

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   162
# Newcastle United            162
# Wolverhampton Wanderers     162
# Crystal Palace              162
# Everton                     162
# Manchester City             162
# Manchester United           162
# West Ham United             162
# Brighton and Hove Albion    162
# Tottenham Hotspur           162
# Aston Villa                 162
# Arsenal                     162
# Chelsea                     162
# Fulham                      124
# Brentford                   124
# Leicester City              124
# Southampton                 124
# Burnley                     114
# Leeds United                114
# Bournemouth                  86
# Nottingham Forest            86
# Sheffield United             76
# Watford                      38
# Norwich City                 38
# West Bromwich Albion         38
# Luton Town                   38
# Ipswich Town                 10
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     100
# Matchweek 3     100
# Matchweek 4     100
# Matchweek 5     100
# Matchweek 6     100
# Matchweek 7     100
# Matchweek 8     100
# Matchweek 9     100
# Matchweek 10    100
# Matchweek 2     100
# Matchweek 32     80
# Matchweek 27     80
# Matchweek 28     80
# Matchweek 30     80
# Matchweek 31     80
# Matchweek 37     80
# Matchweek 33     80
# Matchweek 29     80
# Matchweek 35     80
# Matchweek 36     80
# Matchweek 18     80
# Matchweek 34     80
# Matchweek 26     80
# Matchweek 21     80
# Matchweek 25     80
# Matchweek 24     80
# Matchweek 23     80
# Matchweek 22     80
# Matchweek 20     80
# Matchweek 19     80
# Matchweek 17     80
# Matchweek 16     80
# Matchweek 15     80
# Matchweek 14     80
# Matchweek 13     80
# Matchweek 12     80
# Matchweek 11     80
# Matchweek 38     80
# Name: count, dtype: int64

# %%
#Data Cleaning
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 5  2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk pk  \
# ...

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
#Venue Code = 0 means away and 1 means home
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
#replaces colon and minutes from time with nothing
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"]=matches["date"].dt.dayofweek

# %%
#True is 1 and False is 0
matches["target"] = (matches["result"] == "W").astype("int")

# %%
#doesn't take in higher value opp_codes as more difficult opponents
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=30, random_state=1)

# %%
train = matches[matches["date"] < '2024-01-01']

# %%
test = matches[matches["date"] > '2024-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code", "sh", "sot", "poss", "xg", "xga"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=30, n_estimators=50, random_state=1)

# %%
predictions = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(test["target"], predictions)

# %%
accuracy
# Out:
# 0.7826855123674912

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=predictions))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          303   54
# 1           69  140

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], predictions)
# Out:
# 0.7216494845360825

# %%
#Rolling Averages to imporve precision of the model
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester United").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(4, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt", "season"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 7  2020-10-24  17:30  Premier League   Matchweek 6  Sat  Home      D  0.0
# 9  2020-11-01  16:30  Premier League   Matchweek 7  Sun  Home      L  0.0
# 11 2020-11-07  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 12 2020-11-21  20:00  Premier League   Matchweek 9  Sat  Home      W  1.0
# 14 2020-11-29  14:00  Premier League  Matchweek 10  Sun  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 8  2024-09-29  16:30  Premier League   Matchweek 6  Sun  Home      L  0.0
# 10 2024-10-06  14:00  Premier League   Matchweek 7  Sun  Away      D  0.0
# 11 2024-10-19  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13 2024-10-27  14:00  Premier League   Matchweek 9  Sun  Away      L  1.0
# 15 2024-11-03  16:30  Premier League  Matchweek 10  Sun  Home      D  1.0
#
#      ga     opponent  ...  target  gf_rolling  ga_rolling  sh_rolling  \
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# <ipython-input-482-2d1c64da0b69>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# 14 2020-11-22  16:30  Premier League   Matchweek 9  Sun  Away      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 7  2024-09-28  17:30  Premier League   Matchweek 6  Sat  Home      L  1.0
# 8  2024-10-05  15:00  Premier League   Matchweek 7  Sat  Away      L  3.0
# 9  2024-10-20  14:00  Premier League   Matchweek 8  Sun  Home      L  1.0
# 10 2024-10-26  15:00  Premier League   Matchweek 9  Sat  Away      D  2.0
# 11 2024-11-02  17:30  Premier League  Matchweek 10  Sat  Home      D  2.0
#
#      ga         opponent  ...  target  gf_rolling  ga_rolling  sh_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 1    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 2    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 3    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# 4    2020-11-22  16:30  Premier League   Matchweek 9  Sun  Away      D  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 3123 2024-09-28  17:30  Premier League   Matchweek 6  Sat  Home      L  1.0
# 3124 2024-10-05  15:00  Premier League   Matchweek 7  Sat  Away      L  3.0
# 3125 2024-10-20  14:00  Premier League   Matchweek 8  Sun  Home      L  1.0
# 3126 2024-10-26  15:00  Premier League   Matchweek 9  Sat  Away      D  2.0
# 3127 2024-11-02  17:30  Premier League  Matchweek 10  Sat  Home      D  2.0
#
# ...

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    predictions = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=predictions), index=test.index)
    precision = precision_score(test["target"], predictions)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.7305699481865285

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 130        1          1 2024-01-20                  Arsenal   Crystal Palace
# 131        1          0 2024-01-30                  Arsenal  Nott'ham Forest
# 132        1          1 2024-02-04                  Arsenal        Liverpool
# 133        1          1 2024-02-11                  Arsenal         West Ham
# 134        1          1 2024-02-17                  Arsenal          Burnley
# ...      ...        ...        ...                      ...              ...
# 3123       0          0 2024-09-28  Wolverhampton Wanderers        Liverpool
# 3124       0          0 2024-10-05  Wolverhampton Wanderers        Brentford
# 3125       0          0 2024-10-20  Wolverhampton Wanderers  Manchester City
# 3126       0          0 2024-10-26  Wolverhampton Wanderers         Brighton
# 3127       0          0 2024-11-02  Wolverhampton Wanderers   Crystal Palace
#
#      result
# 130       W
# 131       W
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Nottingham Forest": "Nott'ham Forest", "Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"}
mapping = MissingDict(**map_values)

# %%
mapping["Nottingham Forest"]
# Out:
# "Nott'ham Forest"

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 130        1          1 2024-01-20                  Arsenal   Crystal Palace
# 131        1          0 2024-01-30                  Arsenal  Nott'ham Forest
# 132        1          1 2024-02-04                  Arsenal        Liverpool
# 133        1          1 2024-02-11                  Arsenal         West Ham
# 134        1          1 2024-02-17                  Arsenal          Burnley
# ...      ...        ...        ...                      ...              ...
# 3123       0          0 2024-09-28  Wolverhampton Wanderers        Liverpool
# 3124       0          0 2024-10-05  Wolverhampton Wanderers        Brentford
# 3125       0          0 2024-10-20  Wolverhampton Wanderers  Manchester City
# 3126       0          0 2024-10-26  Wolverhampton Wanderers         Brighton
# 3127       0          0 2024-11-02  Wolverhampton Wanderers   Crystal Palace
#
#      result new_team
# 130       W  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           1            1 2024-01-20                  Arsenal
# 1           1            0 2024-01-30                  Arsenal
# 2           1            1 2024-02-04                  Arsenal
# 3           1            1 2024-02-11                  Arsenal
# 4           1            1 2024-02-17                  Arsenal
# ..        ...          ...        ...                      ...
# 535         0            0 2024-09-28  Wolverhampton Wanderers
# 536         0            0 2024-10-05  Wolverhampton Wanderers
# 537         0            0 2024-10-20  Wolverhampton Wanderers
# 538         0            0 2024-10-26  Wolverhampton Wanderers
# 539         0            0 2024-11-02  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Crystal Palace        W    Arsenal         0            0
# 1    Nott'ham Forest        W    Arsenal         0            0
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    137
# 0     48
# Name: count, dtype: int64

# %%
137 / (137 + 48)
# Out:
# 0.7405405405405405

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'opp formation', 'referee', 'match report', 'notes', 'sh', 'sot',
#        'dist', 'fk', 'pk', 'pkatt', 'season', 'team', 'venue_code', 'opp_code',
#        'hour', 'day_code', 'target'],
#       dtype='object')
